# %%
import mover

# %% [markdown]
# # SAVE MODEL FUNCTION

# %%
#SAVE
model_name= 'Tree558849'
mover.move_model(model_name)
# Out:
# Tree558849
# saved info
# saved backtestdata
# moved pickle
# ALL DONE!!

# %% [markdown]
# # RECALL MODEL FUNCTION

# %%
model_name = 'Tree259551'
model_name= 'Tree558849'
model,info,bt,was_long,was_scaled,up_mpl,dn_mpl = mover.load_model(model_name)
# Out:
# short
# scaled =  True

# %% [markdown]
# ## Info

# %%
info
# Out:
#                                                        Tree558849
# index
# model_id                                               Tree558849
# model_name                                   downed_10!Tree558849
# model_notes                                         default-tree
# stamp                                  2020-10-31 11:23:24.873850
# model_type                                                   Tree
# features        Index(['Open', 'High', 'Low', 'Close', 'Volume...
# true_positive                                  0.7083333333333334
# true_negitive                                  0.6309963099630996
# weighted avg                                   0.6616689599099381
# f1_score                                       0.5552340939556348
# dtrue_positive                                              0.125
# dtrue_negitive                                 0.6715867158671587
# dweighted avg                                  0.5011257739696041
# ...

# %% [markdown]
# ## Backtesting a model

# %%
bt
# Out:
#    strat_id  init_cash  buy_prop  sell_prop  commission execution_type  \
# 4         0       1000         1          1      0.0075          close
# 0         0       1000         1          1      0.0075          close
# 1         0       1000         1          1      0.0075          close
# 6         0       1000         1          1      0.0075          close
# 7         0       1000         1          1      0.0075          close
# 8         0       1000         1          1      0.0075          close
# 3         0       1000         1          1      0.0075          close
# 5         0       1000         1          1      0.0075          close
# 2         0       1000         1          1      0.0075          close
#
#    channel  symbol  buy_int  sell_int  ...     rnorm    rnorm100  sharperatio  \
# 4      NaN     NaN        1        -1  ...  1.543792  154.379178     1.004672
# 0      NaN     NaN        1        -1  ...  1.954001  195.400120     0.961526
# ...

# %% [markdown]
# ## Scale and Direction

# %%
print('was long?:',was_long,'\n was scaled:',was_scaled,)
# Out:
# was long?: False
#  was scaled: True

# %% [markdown]
# ## Best ATR settings

# %%
print('best up_multiple:',up_mpl,'\nbest dn_multiple:',dn_mpl)
# Out:
# best up_multiple: 2
# best dn_multiple: 2

# %% [markdown]
# ## Info

# %%
info
# Out:
#                                                        Tree558849
# index
# model_id                                               Tree558849
# model_name                                   downed_10!Tree558849
# model_notes                                         default-tree
# stamp                                  2020-10-31 11:23:24.873850
# model_type                                                   Tree
# features        Index(['Open', 'High', 'Low', 'Close', 'Volume...
# true_positive                                  0.7083333333333334
# true_negitive                                  0.6309963099630996
# weighted avg                                   0.6616689599099381
# f1_score                                       0.5552340939556348
# dtrue_positive                                              0.125
# dtrue_negitive                                 0.6715867158671587
# dweighted avg                                  0.5011257739696041
# ...

# %% [markdown]
# ##
