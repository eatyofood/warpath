# %% [markdown]
# # TODO:
# ## CLEANING THE SHIT
# ### > ~~label everything or start over~~ hahaha
# ### > ~~each section clearly marked~~
# ### > ~~the ability to add targets and features with one line of code~~
# ### > ~~standardized data input (clearly marked)~~
# ### > make a dot pie version of each [candels,pandas_ta,both]

# %%
import pandas as pd
import os 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_ta as pta

# %%
#data always goes in data
path ='data/'

#d as in directory
d = os.listdir(path)
pd.DataFrame(d,columns=['sheets'])
# Out:
#               sheets
# 0  BATS DMTK, 60.csv

# %%
d
# Out:
# ['BATS DMTK, 60.csv']

# %% [markdown]
# # STANARD DATA LOADING
# #### `Open` `high` `low` `close` `volume` `date`

# %%
sheet = 0
d[sheet]

# loading data
### this part will be replaced by a data loader

df = pd.read_csv(path+d[sheet],index_col='time')
df.index = pd.to_datetime(df.index)#,unit='s')

#df = df[['open','high','low','close','Volume']]
df['date'] = df.index.date
df
# Out:
#                        open    high    low  close  Volume  Volume MA  \
# time
# 2019-09-13 18:30:00   5.940   5.940   5.89   5.89     300     459.20
# 2019-09-13 19:30:00   5.935   5.935   5.88   5.93     700     434.20
# 2019-09-16 13:30:00   5.930   5.930   5.93   5.93     100     434.20
# 2019-09-16 14:30:00   6.000   6.000   5.83   5.83    1300     494.20
# 2019-09-16 15:30:00   6.030   6.030   6.03   6.03     100     438.75
# ...                     ...     ...    ...    ...     ...        ...
# 2020-11-02 15:30:00  12.840  13.000  12.84  13.00     400     428.25
# 2020-11-02 16:30:00  12.820  12.820  12.82  12.82     100     413.25
# 2020-11-02 18:30:00  12.500  12.590  12.50  12.57     400     423.25
# 2020-11-02 19:30:00  12.610  12.610  12.61  12.61     140     415.25
# 2020-11-02 20:30:00  13.000  13.000  12.82  12.85     800     440.25
#
#                      Edge Line    Plot  Plot.1  Plot.2  ...  Plot.9  Plot.10  \
# time                                                    ...
# 2019-09-13 18:30:00   6.360914  21.147  19.133    5.72  ...     0.0      0.0
# 2019-09-13 19:30:00   6.360914  21.147  19.133    5.89  ...     0.0      0.0
# 2019-09-16 13:30:00   6.360914  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 14:30:00   6.315995  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 15:30:00   6.288993  21.147  19.133    5.83  ...     0.0      0.0
# ...                        ...     ...     ...     ...  ...     ...      ...
# 2020-11-02 15:30:00  11.780473  11.823  10.697   13.04  ...   100.0    100.0
# 2020-11-02 16:30:00  11.870329  11.823  10.697   13.00  ...   100.0    100.0
# 2020-11-02 18:30:00  11.940800  11.823  10.697   12.82  ...   100.0    100.0
# 2020-11-02 19:30:00  11.940800  11.823  10.697   12.57  ...   100.0    100.0
# 2020-11-02 20:30:00  11.940800  11.823  10.697   12.61  ...   100.0    100.0
#
#                      storeversal  sto oversold  buyssto  Unnamed: 77  \
# time
# 2019-09-13 18:30:00          0.0           0.0      0.0          0.0
# 2019-09-13 19:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 13:30:00          0.0           0.0      0.0          1.0
# 2019-09-16 14:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 15:30:00          0.0           0.0      0.0          0.0
# ...                          ...           ...      ...          ...
# 2020-11-02 15:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 16:30:00          1.0           0.0      0.0          1.0
# 2020-11-02 18:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 19:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 20:30:00          0.0           0.0      0.0          0.0
#
#                      third smack.1  weeklyup  monthlyup        date
# time
# 2019-09-13 18:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-13 19:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-16 13:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 14:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 15:30:00            1.0       0.0        0.0  2019-09-16
# ...                            ...       ...        ...         ...
# 2020-11-02 15:30:00            1.0       1.0        1.0  2020-11-02
# 2020-11-02 16:30:00            1.0       1.0        1.0  2020-11-02
# 2020-11-02 18:30:00            1.0       1.0        0.0  2020-11-02
# 2020-11-02 19:30:00            1.0       1.0        0.0  2020-11-02
# 2020-11-02 20:30:00            0.0       1.0        0.0  2020-11-02
#
# [1272 rows x 61 columns]

# %% [markdown]
# # From Here On Data Should Look Like that
# ### doesnt matter if its from downloader or what
# #### [datetimeindex open 	high 	low 	close 	Volume 	date]

# %% [markdown]
# # Technical aylisis features

# %%
import ta

#df = ta.add_all_ta_features(df,'open','high','low','close','Volume',fillna=True)

# %% [markdown]
# # Candels features

# %%
df.index
# Out:
# DatetimeIndex(['2019-09-13 18:30:00', '2019-09-13 19:30:00',
#                '2019-09-16 13:30:00', '2019-09-16 14:30:00',
#                '2019-09-16 15:30:00', '2019-09-16 17:30:00',
#                '2019-09-16 18:30:00', '2019-09-16 19:30:00',
#                '2019-09-17 19:30:00', '2019-09-18 13:30:00',
#                ...
#                '2020-10-30 15:30:00', '2020-10-30 16:30:00',
#                '2020-10-30 17:30:00', '2020-10-30 18:30:00',
#                '2020-11-02 14:30:00', '2020-11-02 15:30:00',
#                '2020-11-02 16:30:00', '2020-11-02 18:30:00',
#                '2020-11-02 19:30:00', '2020-11-02 20:30:00'],
#               dtype='datetime64[ns]', name='time', length=1272, freq=None)

# %%
#import candle_sticks
#import daily_close_compare

# adds all the candel patterns
#candle_sticks.all_candels(df)

#adds the daily_close_comparison class i made [which the day checker is not working btw]
#df = daily_close_compare.create_anna(df)

#plot empty values... candel sticks dont make any nul values
#sns.heatmap(df.isnull())

# %%
#pd.set_option('display.max_columns',None)
#df

# %%
print(len(df.columns))
df.head()
# Out:
# 61
#                       open   high   low  close  Volume  Volume MA  Edge Line  \
# time
# 2019-09-13 18:30:00  5.940  5.940  5.89   5.89     300     459.20   6.360914
# 2019-09-13 19:30:00  5.935  5.935  5.88   5.93     700     434.20   6.360914
# 2019-09-16 13:30:00  5.930  5.930  5.93   5.93     100     434.20   6.360914
# 2019-09-16 14:30:00  6.000  6.000  5.83   5.83    1300     494.20   6.315995
# 2019-09-16 15:30:00  6.030  6.030  6.03   6.03     100     438.75   6.288993
#
#                        Plot  Plot.1  Plot.2  ...  Plot.9  Plot.10  \
# time                                         ...
# 2019-09-13 18:30:00  21.147  19.133    5.72  ...     0.0      0.0
# 2019-09-13 19:30:00  21.147  19.133    5.89  ...     0.0      0.0
# 2019-09-16 13:30:00  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 14:30:00  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 15:30:00  21.147  19.133    5.83  ...     0.0      0.0
#
#                      storeversal  sto oversold  buyssto  Unnamed: 77  \
# time
# 2019-09-13 18:30:00          0.0           0.0      0.0          0.0
# 2019-09-13 19:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 13:30:00          0.0           0.0      0.0          1.0
# 2019-09-16 14:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 15:30:00          0.0           0.0      0.0          0.0
#
#                      third smack.1  weeklyup  monthlyup        date
# time
# 2019-09-13 18:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-13 19:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-16 13:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 14:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 15:30:00            1.0       0.0        0.0  2019-09-16
#
# [5 rows x 61 columns]

# %%
print('length of dataset is:',len(df))
print('length of features is:',len(df.columns))

# you are supposed to have 5 times as many rows as columns at a minmum for ml
five_times_col = len(df.columns)*5
print('maximum features:',five_times_col)
# Out:
# length of dataset is: 1272
# length of features is: 61
# maximum features: 305

# %%
#standardizing data
df = df.rename(columns={'close':'Close',
               'open':'Open',
               'low':'Low',
               'high':'High',
               })
df
# Out:
#                        Open    High    Low  Close  Volume  Volume MA  \
# time
# 2019-09-13 18:30:00   5.940   5.940   5.89   5.89     300     459.20
# 2019-09-13 19:30:00   5.935   5.935   5.88   5.93     700     434.20
# 2019-09-16 13:30:00   5.930   5.930   5.93   5.93     100     434.20
# 2019-09-16 14:30:00   6.000   6.000   5.83   5.83    1300     494.20
# 2019-09-16 15:30:00   6.030   6.030   6.03   6.03     100     438.75
# ...                     ...     ...    ...    ...     ...        ...
# 2020-11-02 15:30:00  12.840  13.000  12.84  13.00     400     428.25
# 2020-11-02 16:30:00  12.820  12.820  12.82  12.82     100     413.25
# 2020-11-02 18:30:00  12.500  12.590  12.50  12.57     400     423.25
# 2020-11-02 19:30:00  12.610  12.610  12.61  12.61     140     415.25
# 2020-11-02 20:30:00  13.000  13.000  12.82  12.85     800     440.25
#
#                      Edge Line    Plot  Plot.1  Plot.2  ...  Plot.9  Plot.10  \
# time                                                    ...
# 2019-09-13 18:30:00   6.360914  21.147  19.133    5.72  ...     0.0      0.0
# 2019-09-13 19:30:00   6.360914  21.147  19.133    5.89  ...     0.0      0.0
# 2019-09-16 13:30:00   6.360914  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 14:30:00   6.315995  21.147  19.133    5.93  ...     0.0      0.0
# 2019-09-16 15:30:00   6.288993  21.147  19.133    5.83  ...     0.0      0.0
# ...                        ...     ...     ...     ...  ...     ...      ...
# 2020-11-02 15:30:00  11.780473  11.823  10.697   13.04  ...   100.0    100.0
# 2020-11-02 16:30:00  11.870329  11.823  10.697   13.00  ...   100.0    100.0
# 2020-11-02 18:30:00  11.940800  11.823  10.697   12.82  ...   100.0    100.0
# 2020-11-02 19:30:00  11.940800  11.823  10.697   12.57  ...   100.0    100.0
# 2020-11-02 20:30:00  11.940800  11.823  10.697   12.61  ...   100.0    100.0
#
#                      storeversal  sto oversold  buyssto  Unnamed: 77  \
# time
# 2019-09-13 18:30:00          0.0           0.0      0.0          0.0
# 2019-09-13 19:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 13:30:00          0.0           0.0      0.0          1.0
# 2019-09-16 14:30:00          0.0           0.0      0.0          0.0
# 2019-09-16 15:30:00          0.0           0.0      0.0          0.0
# ...                          ...           ...      ...          ...
# 2020-11-02 15:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 16:30:00          1.0           0.0      0.0          1.0
# 2020-11-02 18:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 19:30:00          0.0           0.0      0.0          0.0
# 2020-11-02 20:30:00          0.0           0.0      0.0          0.0
#
#                      third smack.1  weeklyup  monthlyup        date
# time
# 2019-09-13 18:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-13 19:30:00            1.0       0.0        0.0  2019-09-13
# 2019-09-16 13:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 14:30:00            1.0       0.0        0.0  2019-09-16
# 2019-09-16 15:30:00            1.0       0.0        0.0  2019-09-16
# ...                            ...       ...        ...         ...
# 2020-11-02 15:30:00            1.0       1.0        1.0  2020-11-02
# 2020-11-02 16:30:00            1.0       1.0        1.0  2020-11-02
# 2020-11-02 18:30:00            1.0       1.0        0.0  2020-11-02
# 2020-11-02 19:30:00            1.0       1.0        0.0  2020-11-02
# 2020-11-02 20:30:00            0.0       1.0        0.0  2020-11-02
#
# [1272 rows x 61 columns]

# %%
df = df.drop('date',axis=1)

# %%
from sklearn.preprocessing import StandardScaler

def scale(df):
    scaler = StandardScaler()
    scaled = scaler.fit_transform(df)
    sdf    = pd.DataFrame(scaled,columns = df.columns)
    sdf.index = df.index
    return sdf

# %%
# if there is nulls you want them to be at the beggining 
sns.heatmap(df[:50].isnull())

# %%
#if there are nulls here SOMTHING IS WRONG and yourleaking data
sns.heatmap(df[50:].isnull())

# %% [markdown]
# # Targets

# %%
import add_targets

# %%
#making the features data a copy so its unaffected by adding targets
fdf = df.copy()

# %%
#standard deviation based targets (default is .5,1,2)
tdf ,rhs,ts= add_targets.std_targs(df)
#tdf is for target_df
tdf
# Out:
# these ARE targets!:
#  ['Close', 'STDR10:down_target:_2!', 'STDR10:down_target:_1!', 'STDR10:down_target:_0.5!', 'STDR10:up_target:_0.5!', 'STDR10:up_target:_1!', 'STDR10:up_target:_2!']
# /home/brado/algos/Falling Furry/Research/DMTK/WARPATH/hourly/ML_WARPATH-V2./add_targets.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[rollingh] = df.High.rolling(hi_rol_lo).max()
# /home/brado/algos/Falling Furry/Research/DMTK/WARPATH/hourly/ML_WARPATH-V2./add_targets.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[rollingl] = df.Low.rolling(hi_rol_lo).min()
#                        Open    High    Low  Close  Volume  Volume MA  \
# time
# 2019-09-13 18:30:00   5.940   5.940   5.89   5.89     300     459.20
# 2019-09-13 19:30:00   5.935   5.935   5.88   5.93     700     434.20
# 2019-09-16 13:30:00   5.930   5.930   5.93   5.93     100     434.20
# 2019-09-16 14:30:00   6.000   6.000   5.83   5.83    1300     494.20
# 2019-09-16 15:30:00   6.030   6.030   6.03   6.03     100     438.75
# ...                     ...     ...    ...    ...     ...        ...
# 2020-11-02 15:30:00  12.840  13.000  12.84  13.00     400     428.25
# 2020-11-02 16:30:00  12.820  12.820  12.82  12.82     100     413.25
# 2020-11-02 18:30:00  12.500  12.590  12.50  12.57     400     423.25
# 2020-11-02 19:30:00  12.610  12.610  12.61  12.61     140     415.25
# 2020-11-02 20:30:00  13.000  13.000  12.82  12.85     800     440.25
#
#                      Edge Line    Plot  Plot.1  Plot.2  ...  \
# time                                                    ...
# 2019-09-13 18:30:00   6.360914  21.147  19.133    5.72  ...
# 2019-09-13 19:30:00   6.360914  21.147  19.133    5.89  ...
# 2019-09-16 13:30:00   6.360914  21.147  19.133    5.93  ...
# 2019-09-16 14:30:00   6.315995  21.147  19.133    5.93  ...
# 2019-09-16 15:30:00   6.288993  21.147  19.133    5.83  ...
# ...                        ...     ...     ...     ...  ...
# 2020-11-02 15:30:00  11.780473  11.823  10.697   13.04  ...
# 2020-11-02 16:30:00  11.870329  11.823  10.697   13.00  ...
# 2020-11-02 18:30:00  11.940800  11.823  10.697   12.82  ...
# 2020-11-02 19:30:00  11.940800  11.823  10.697   12.57  ...
# 2020-11-02 20:30:00  11.940800  11.823  10.697   12.61  ...
#
#                      STDR10:up_target:_2!  STDR10:down_target:_2!  \
# time
# 2019-09-13 18:30:00                   NaN                     NaN
# 2019-09-13 19:30:00                   NaN                     NaN
# 2019-09-16 13:30:00                   NaN                     NaN
# 2019-09-16 14:30:00                   NaN                     NaN
# 2019-09-16 15:30:00                   NaN                     NaN
# ...                                   ...                     ...
# 2020-11-02 15:30:00             13.973142               11.866858
# 2020-11-02 16:30:00             13.637341               12.002659
# 2020-11-02 18:30:00             13.099711               11.990289
# 2020-11-02 19:30:00             13.049476               12.170524
# 2020-11-02 20:30:00             13.339321               12.480679
#
#                      High_ahead!  Low_ahead!  STDR10:down_target:_2_HIT!  \
# time
# 2019-09-13 18:30:00         6.03         5.5                       False
# 2019-09-13 19:30:00         6.03         5.5                       False
# 2019-09-16 13:30:00         6.03         5.5                       False
# 2019-09-16 14:30:00         6.03         5.5                       False
# 2019-09-16 15:30:00         6.03         5.5                       False
# ...                          ...         ...                         ...
# 2020-11-02 15:30:00          NaN         NaN                       False
# 2020-11-02 16:30:00          NaN         NaN                       False
# 2020-11-02 18:30:00          NaN         NaN                       False
# 2020-11-02 19:30:00          NaN         NaN                       False
# 2020-11-02 20:30:00          NaN         NaN                       False
#
#                      STDR10:down_target:_1_HIT!  STDR10:down_target:_0.5_HIT!  \
# time
# 2019-09-13 18:30:00                       False                         False
# 2019-09-13 19:30:00                       False                         False
# 2019-09-16 13:30:00                       False                         False
# 2019-09-16 14:30:00                       False                         False
# 2019-09-16 15:30:00                       False                         False
# ...                                         ...                           ...
# 2020-11-02 15:30:00                       False                         False
# 2020-11-02 16:30:00                       False                         False
# 2020-11-02 18:30:00                       False                         False
# 2020-11-02 19:30:00                       False                         False
# 2020-11-02 20:30:00                       False                         False
#
#                      STDR10:up_target:_0.5_HIT!  STDR10:up_target:_1_HIT!  \
# time
# 2019-09-13 18:30:00                       False                     False
# 2019-09-13 19:30:00                       False                     False
# 2019-09-16 13:30:00                       False                     False
# 2019-09-16 14:30:00                       False                     False
# 2019-09-16 15:30:00                       False                     False
# ...                                         ...                       ...
# 2020-11-02 15:30:00                       False                     False
# 2020-11-02 16:30:00                       False                     False
# 2020-11-02 18:30:00                       False                     False
# 2020-11-02 19:30:00                       False                     False
# 2020-11-02 20:30:00                       False                     False
#
#                      STDR10:up_target:_2_HIT!
# time
# 2019-09-13 18:30:00                     False
# 2019-09-13 19:30:00                     False
# 2019-09-16 13:30:00                     False
# 2019-09-16 14:30:00                     False
# 2019-09-16 15:30:00                     False
# ...                                       ...
# 2020-11-02 15:30:00                     False
# 2020-11-02 16:30:00                     False
# 2020-11-02 18:30:00                     False
# 2020-11-02 19:30:00                     False
# 2020-11-02 20:30:00                     False
#
# [1272 rows x 75 columns]

# %%
#adding % based targets
tdf = add_targets.add_targets(tdf)
tdf.columns
# Out:
# /home/brado/algos/Falling Furry/Research/DMTK/WARPATH/hourly/ML_WARPATH-V2./add_targets.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Highlast_10!'] = df['High'].rolling(10).max()
# /home/brado/algos/Falling Furry/Research/DMTK/WARPATH/hourly/ML_WARPATH-V2./add_targets.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Lowlast_10!'] = df['Low'].rolling(10).min()
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Volume MA', 'Edge Line',
#        'Plot', 'Plot.1', 'Plot.2', 'Plot.3', 'Plot.4', 'VMA.6', 'Edge Line.1',
#        'super_trend_up', 'super_trend_down', 'smack_down', 'up_smack',
#        'Shapes', 'stop_loss', 'VMA.7', 'Edge Line.2', 'first smack',
#        'long trailingn stop', 'short trailingn stop', 'stop_percentage',
#        'actual_stop', 'third smack', 'second smack', 'first smack.1',
#        'first smack.2', 'elliot wave ocolator', 'vwaprizz14', 'vwaprizz14_ema',
#        'Plot.5', 'Plot.6', 'RIZZY-2', 'buy', 'sell_sig', 'sell_sig.2',
#        'sell_sig.3', 'test', 'rizzy', 'sto1', 'sto2', 'Plot.7', 'Plot.8',
#        'weeklysto1', 'weeklysto2', 'monthlysto1', 'monthlysto2', 'Plot.9',
#        'Plot.10', 'storeversal', 'sto oversold', 'buyssto', 'Unnamed: 77',
#        'third smack.1', 'weeklyup', 'monthlyup', 'STD',
#        'STDR10:up_target:_0.5!', 'STDR10:down_target:_0.5!',
#        'STDR10:up_target:_1!', 'STDR10:down_target:_1!',
#        'STDR10:up_target:_2!', 'STDR10:down_target:_2!', 'High_ahead!',
#        'Low_ahead!', 'STDR10:down_target:_2_HIT!',
#        'STDR10:down_target:_1_HIT!', 'STDR10:down_target:_0.5_HIT!',
#        'STDR10:up_target:_0.5_HIT!', 'STDR10:up_target:_1_HIT!',
#        'STDR10:up_target:_2_HIT!', 'plus_10!', 'minus_10!', 'plus_20!',
#        'minus_20!', 'minus_5!', 'plus_5!', 'Highlast_10!', 'Lowlast_10!',
#        'uped_10!', 'downed_10!', 'uped_20!', 'downed_20!', 'uped_5!',
#        'downed_5!'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %%
tdf
# Out:
#                        Open    High    Low  Close  Volume  Volume MA  \
# time
# 2019-09-13 18:30:00   5.940   5.940   5.89   5.89     300     459.20
# 2019-09-13 19:30:00   5.935   5.935   5.88   5.93     700     434.20
# 2019-09-16 13:30:00   5.930   5.930   5.93   5.93     100     434.20
# 2019-09-16 14:30:00   6.000   6.000   5.83   5.83    1300     494.20
# 2019-09-16 15:30:00   6.030   6.030   6.03   6.03     100     438.75
# ...                     ...     ...    ...    ...     ...        ...
# 2020-11-02 15:30:00  12.840  13.000  12.84  13.00     400     428.25
# 2020-11-02 16:30:00  12.820  12.820  12.82  12.82     100     413.25
# 2020-11-02 18:30:00  12.500  12.590  12.50  12.57     400     423.25
# 2020-11-02 19:30:00  12.610  12.610  12.61  12.61     140     415.25
# 2020-11-02 20:30:00  13.000  13.000  12.82  12.85     800     440.25
#
#                      Edge Line    Plot  Plot.1  Plot.2  Plot.3  Plot.4  \
# time
# 2019-09-13 18:30:00   6.360914  21.147  19.133    5.72   5.450   5.450
# 2019-09-13 19:30:00   6.360914  21.147  19.133    5.89   5.720   5.720
# 2019-09-16 13:30:00   6.360914  21.147  19.133    5.93   5.890   5.940
# 2019-09-16 14:30:00   6.315995  21.147  19.133    5.93   5.930   5.935
# 2019-09-16 15:30:00   6.288993  21.147  19.133    5.83   5.930   5.930
# ...                        ...     ...     ...     ...     ...     ...
# 2020-11-02 15:30:00  11.780473  11.823  10.697   13.04  12.715  12.790
# 2020-11-02 16:30:00  11.870329  11.823  10.697   13.00  13.000  13.040
# 2020-11-02 18:30:00  11.940800  11.823  10.697   12.82  12.840  13.000
# 2020-11-02 19:30:00  11.940800  11.823  10.697   12.57  12.820  12.820
# 2020-11-02 20:30:00  11.940800  11.823  10.697   12.61  12.500  12.570
#
#                          VMA.6  Edge Line.1  super_trend_up  super_trend_down  \
# time
# 2019-09-13 18:30:00   5.157951     6.360914        4.452165          6.360914
# 2020-11-02 16:30:00       1.0        1.0  0.408670               13.024335
# 2020-11-02 18:30:00       1.0        0.0  0.254856               12.717428
# 2020-11-02 19:30:00       1.0        0.0  0.219738               12.719869
# 2020-11-02 20:30:00       1.0        0.0  0.169661               13.084830
#
#                      STDR10:down_target:_0.5!  STDR10:up_target:_1!  \
# time
# 2019-09-13 18:30:00                       NaN                   NaN
# 2019-09-13 19:30:00                       NaN                   NaN
# 2019-09-16 13:30:00                       NaN                   NaN
# 2019-09-16 14:30:00                       NaN                   NaN
# 2019-09-16 15:30:00                       NaN                   NaN
# ...                                       ...                   ...
# 2020-11-02 15:30:00                 12.596714             13.486571
# 2020-11-02 16:30:00                 12.615665             13.228670
# 2020-11-02 18:30:00                 12.372572             12.844856
# 2020-11-02 19:30:00                 12.500131             12.829738
# 2020-11-02 20:30:00                 12.735170             13.169661
#
#                      STDR10:down_target:_1!  STDR10:up_target:_2!  \
# time
# 2019-09-13 18:30:00                     NaN                   NaN
# 2019-09-13 19:30:00                     NaN                   NaN
# 2019-09-16 13:30:00                     NaN                   NaN
# 2019-09-16 14:30:00                     NaN                   NaN
# 2019-09-16 15:30:00                     NaN                   NaN
# ...                                     ...                   ...
# 2020-11-02 15:30:00               12.353429             13.973142
# 2020-11-02 16:30:00               12.411330             13.637341
# 2020-11-02 18:30:00               12.245144             13.099711
# 2020-11-02 19:30:00               12.390262             13.049476
# 2020-11-02 20:30:00               12.650339             13.339321
#
#                      STDR10:down_target:_2!  High_ahead!  Low_ahead!  \
# time
# 2019-09-13 18:30:00                     NaN         6.03         5.5
# 2019-09-13 19:30:00                     NaN         6.03         5.5
# 2019-09-16 13:30:00                     NaN         6.03         5.5
# 2019-09-16 14:30:00                     NaN         6.03         5.5
# 2019-09-16 15:30:00                     NaN         6.03         5.5
# ...                                     ...          ...         ...
# 2020-11-02 15:30:00               11.866858          NaN         NaN
# 2020-11-02 16:30:00               12.002659          NaN         NaN
# 2020-11-02 18:30:00               11.990289          NaN         NaN
# 2020-11-02 19:30:00               12.170524          NaN         NaN
# 2020-11-02 20:30:00               12.480679          NaN         NaN
#
#                      STDR10:down_target:_2_HIT!  STDR10:down_target:_1_HIT!  \
# time
# 2019-09-13 18:30:00                       False                       False
# 2019-09-13 19:30:00                       False                       False
# 2019-09-16 13:30:00                       False                       False
# 2019-09-16 14:30:00                       False                       False
# 2019-09-16 15:30:00                       False                       False
# ...                                         ...                         ...
# 2020-11-02 15:30:00                       False                       False
# 2020-11-02 16:30:00                       False                       False
# 2020-11-02 18:30:00                       False                       False
# 2020-11-02 19:30:00                       False                       False
# 2020-11-02 20:30:00                       False                       False
#
#                      STDR10:down_target:_0.5_HIT!  STDR10:up_target:_0.5_HIT!  \
# time
# 2019-09-13 18:30:00                         False                       False
# 2019-09-13 19:30:00                         False                       False
# 2019-09-16 13:30:00                         False                       False
# 2019-09-16 14:30:00                         False                       False
# 2019-09-16 15:30:00                         False                       False
# %% [markdown]
# ### It should contain nulls

# %%
sns.heatmap(tdf.isnull())

# %% [markdown]
# ### Check the first 50

# %%
sns.heatmap(tdf[:50].isnull())

# %% [markdown]
# ### Check the last 50

# %%
tdf = tdf.dropna(axis=0)
print(len(tdf))
sns.heatmap(tdf.isnull())
print(len(tdf))
# Out:
# 1254
# 1254

# %%
#but now there are differnces in the legnths
print(len(tdf),len(fdf))
# Out:
# 1254 1272

# %%
#so use the index as a cookie cutter template to have the exact same values
fdf = fdf.T[tdf.T.columns].T
print('target_len',len(tdf))

print( 'feature_len',len(fdf))
# Out:
# target_len 1254
# feature_len 1254

# %%
sns.heatmap(tdf.isnull())

# %%
sns.heatmap(fdf.isnull())

# %% [markdown]
# # scale

# %%
sdf = scale(fdf)

# %%
sns.heatmap(sdf.isnull())

# %% [markdown]
# # Save Clean Parsed Data

# %%
#create the clean data_path if it doesnt already exist
cpath = 'clean_data/'
if not os.path.exists(cpath):
    os.mkdir(cpath)

#name em
tname = 'targets_'+d[sheet]
fname = 'features_'+d[sheet]
sname = 'scaled_'+d[sheet]


#save em
tdf.to_csv(cpath+tname)
fdf.to_csv(cpath+fname)
sdf.to_csv(cpath+sname)

# %% [markdown]
# ## what if i try to predict its favorite movin avg cross over?

# %% [markdown]
# # this is the candel script

# %% [markdown]
# # this sheet creates features and cleans data
# ## GOALS  of this research project
# ### >anylize coeficaints on features which work best
# #### `pandas_ta` `candels` `homebrew`
# ### > create feature scripts that can run in shell_scripts for data downloaders
#
# t sheet
# ## this should be iterable for the sheets in the dir
#
# sheet = 0
# for sheet in range(0,len(d)):
#
#
#     # candels
#
#     import candle_sticks
#     import daily_close_compare
#
#     df = daily_close_compare.create_anna(df)
#
#     candle_sticks.all_candels(df)
#
#     df = df.dropna(axis=0)
#     sns.heatmap(df.isnull())
#
#     cpath = 'clean_data/'
#     if not os.path.exists(cpath):
#         print('chayyyayyayya')
#         os.mkdir(cpath)
#
#     if 'date' in df.columns:
#         df = df.drop('date',axis=1)
#
#     name = d[sheet]
#     name = name.split('.')[0].replace(' ','_').replace(',','') +'_candels.csv'
#     name
#
#
#     df.to_csv(cpath+name)

# %%
fdf
# Out:
#                        Open    High    Low   Close  Volume  Volume MA  \
# time
# 2019-09-18 13:30:00   5.560   5.560   5.56   5.560   100.0     364.00
# 2019-09-18 19:30:00   5.660   5.660   5.63   5.630   700.0     394.00
# 2019-09-19 13:30:00   5.875   6.010   5.80   6.000  1405.0     459.25
# 2019-09-19 14:30:00   5.850   6.015   5.85   6.015  1200.0     514.25
# 2019-09-19 18:30:00   6.000   6.000   6.00   6.000   600.0     534.25
# ...                     ...     ...    ...     ...     ...        ...
# 2020-10-29 18:30:00  11.830  11.830  11.83  11.830   100.0     294.75
# 2020-10-29 19:30:00  11.820  11.820  11.74  11.760   300.0     289.75
# 2020-10-30 13:30:00  12.290  12.360  12.28  12.360   300.0     294.75
# 2020-10-30 14:30:00  12.340  12.400  12.34  12.400   700.0     299.75
#                      sto oversold  buyssto  Unnamed: 77  third smack.1  \
# time
# 2019-09-18 13:30:00           0.0      0.0          0.0            1.0
# 2019-09-18 19:30:00           0.0      0.0          0.0            0.0
# 2019-09-19 13:30:00           0.0      0.0          0.0            0.0
# 2019-09-19 14:30:00           0.0      0.0          0.0            1.0
# 2019-09-19 18:30:00           0.0      0.0          0.0            1.0
# ...                           ...      ...          ...            ...
# 2020-10-29 18:30:00           0.0      0.0          0.0            1.0
# 2020-10-29 19:30:00           0.0      0.0          0.0            1.0
# 2020-10-30 13:30:00           0.0      0.0          0.0            0.0
# 2020-10-30 14:30:00           0.0      0.0          0.0            0.0
# 2020-10-30 15:30:00           0.0      0.0          0.0            1.0
#
#                      weeklyup  monthlyup
# time
# 2019-09-18 13:30:00       0.0        1.0
# 2019-09-18 19:30:00       0.0        1.0
# 2019-09-19 13:30:00       0.0        1.0
# 2019-09-19 14:30:00       0.0        1.0
# 2019-09-19 18:30:00       0.0        1.0
# ...                       ...        ...
# 2020-10-29 18:30:00       1.0        1.0
# 2020-10-29 19:30:00       1.0        1.0
# 2020-10-30 13:30:00       1.0        1.0
# 2020-10-30 14:30:00       1.0        1.0
# 2020-10-30 15:30:00       1.0        1.0
#
# [1254 rows x 60 columns]

# %% [markdown]
# # this sheet creates features and cleans data
# ## GOALS  of this research project
# ### >anylize coeficaints on features which work best
# #### `pandas_ta` `candels` `homebrew`
# ### > create feature scripts that can run in shell_scripts for data downloaders
#
#
# import pandas as pd
# import os
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
#
#
# path ='../../data/'
#
# d = os.listdir(path)
# pd.DataFrame(d,columns=['sheets'])
#
# # selecgt sheet
# ## this should be iterable for the sheets in the dir
#
# sheet = 0
# d[sheet]
#
# # loading data
# ### this part will be replaced by a data loader
#
# df = pd.read_csv(path+d[sheet],index_col='time')
# df.index = pd.to_datetime(df.index,unit='s')
#
# df = df[['open','high','low','close']]
# df['date'] = df.index
#
# # candels
#
# import candle_sticks
# import daily_close_compare
#
# df = daily_close_compare.create_anna(df)
#
# candle_sticks.all_candels(df)
#
# df = df.dropna(axis=0)
# sns.heatmap(df.isnull())
#
# cpath = 'clean_data/'
# if not os.path.exists(cpath):
#     print('chayyyayyayya')
#     os.mkdir(cpath)
#
# if 'date' in df.columns:
#     df = df.drop('date',axis=1)
#
# name = d[sheet]
# name = name.split('.')[0].replace(' ','_').replace(',','') +'_candels.csv'
# name
#
#
# df.to_csv(cpath+name)

# %% [markdown]
# # its possible the scale was fucking up so bad b/c its index was not properly called...

# %% [markdown]
# # merged no features

# %% [markdown]
# import pandas as pd
# import os
# import seaborn as sns
# import matplotlib.pyplot as plt
# %matplotlib inline
# import pandas_ta as pta
#
#
# #data always goes in data
# path ='data/'
#
# #d as in directory
# d = os.listdir(path)
# pd.DataFrame(d,columns=['sheets'])
#
# d
#
# # STANARD DATA LOADING
# #### `Open` `high` `low` `close` `volume` `date`
#
# sheet = 0
# d[sheet]
#
# # loading data
# ### this part will be replaced by a data loader
#
# df = pd.read_csv(path+d[sheet],index_col='time')
# df.index = pd.to_datetime(df.index)#,unit='s')
#
# #df = df[['open','high','low','close','Volume']]
# df['date'] = df.index.date
# df
#
#
# # From Here On Data Should Look Like that
# ### doesnt matter if its from downloader or what
# #### [datetimeindex open 	high 	low 	close 	Volume 	date]
#
# # Technical aylisis features
#
# import ta
#
# #df = ta.add_all_ta_features(df,'open','high','low','close','Volume',fillna=True)
#
# # Candels features
#
# df.index
#
# #import candle_sticks
# #import daily_close_compare
#
# # adds all the candel patterns
# #candle_sticks.all_candels(df)
#
# #adds the daily_close_comparison class i made [which the day checker is not working btw]
# #df = daily_close_compare.create_anna(df)
#
# #plot empty values... candel sticks dont make any nul values
# #sns.heatmap(df.isnull())
#
# #pd.set_option('display.max_columns',None)
# #df
#
# print(len(df.columns))
# df.head()
#
# print('length of dataset is:',len(df))
# print('length of features is:',len(df.columns))
#
# # you are supposed to have 5 times as many rows as columns at a minmum for ml
# five_times_col = len(df.columns)*5
# print('maximum features:',five_times_col)
#
# #standardizing data
# df = df.rename(columns={'close':'Close',
#                'open':'Open',
#                'low':'Low',
#                'high':'High',
#                })
# df
#
# df = df.drop('date',axis=1)
#
# from sklearn.preprocessing import StandardScaler
#
# def scale(df):
#     scaler = StandardScaler()
#     scaled = scaler.fit_transform(df)
#     sdf    = pd.DataFrame(scaled,columns = df.columns)
#     sdf.index = df.index
#     return sdf
#
# # if there is nulls you want them to be at the beggining
# sns.heatmap(df[:50].isnull())
#
# #if there are nulls here SOMTHING IS WRONG and yourleaking data
# sns.heatmap(df[50:].isnull())
#
# # Targets
#
# import add_targets
#
# #making the features data a copy so its unaffected by adding targets
# fdf = df.copy()
#
# #standard deviation based targets (default is .5,1,2)
# tdf ,rhs,ts= add_targets.std_targs(df)
# #tdf is for target_df
# tdf
#
# #adding % based targets
# tdf = add_targets.add_targets(tdf)
# tdf.columns
#
# pd.set_option('display.max_columns',None)
#
# tdf
#
# ### It should contain nulls
#
# sns.heatmap(tdf.isnull())
#
# ### Check the first 50
#
# sns.heatmap(tdf[:50].isnull())
#
# ### Check the last 50
#
# tdf = tdf.dropna(axis=0)
# print(len(tdf))
# sns.heatmap(tdf.isnull())
# print(len(tdf))
#
# #but now there are differnces in the legnths
# print(len(tdf),len(fdf))
#
#
#
# #so use the index as a cookie cutter template to have the exact same values
# fdf = fdf.T[tdf.T.columns].T
# print('target_len',len(tdf))
#
# print( 'feature_len',len(fdf))
#
# sns.heatmap(tdf.isnull())
#
#
# sns.heatmap(fdf.isnull())
#
# # scale
#
# sdf = scale(fdf)
#
#
# sns.heatmap(sdf.isnull())
#
# # Save Clean Parsed Data
#
# #create the clean data_path if it doesnt already exist
# cpath = 'clean_data/'
# if not os.path.exists(cpath):
#     os.mkdir(cpath)
#
# #name em
# tname = 'targets_'+d[sheet]
# fname = 'features_'+d[sheet]
# sname = 'scaled_'+d[sheet]
#
#
# #save em
# tdf.to_csv(cpath+tname)
# fdf.to_csv(cpath+fname)
# sdf.to_csv(cpath+sname)
